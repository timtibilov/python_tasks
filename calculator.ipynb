# %% [markdown]
# # Арифметика. Функции. Ввод и вывод.
#
# ## Задание 1.
#
# Требуется реализовать:
# 1. Функцию `arithmetic`, которая будет принимать на вход два числа и строковую переменную, означающую арифметическую операцию `+`, `-`, `*`, `/`, `%` или `//`.
# Функция должна вернуть число - результат арифметической операции над двумя числами. Если на вход были получены не числа или несуществующая операция, то нужно вернуть сообщение `"Unknown operand type and (or) operation"`.
#
# 2. Функцию `get_input`, которая ничего не будет принимать на вход и будет возвращать `tuple` из 3-х элементов: первого числа, второго числа и оператора между ними. Ввод значений можно сделать в свободной форме (либо просить ввести весь пример сразу и далее корректно его обработать, либо просить вводить каждое значение по отдельности). Предполагается, что оператор не будет вводить некорректные значения.
#
# 3. Функцию `main`, которая ничего не принимает на вход и ничего не возвращает. Внутри она должна предлагать пользователю посчитать пример, пока пользователь не введет `exit` или не захочет выйти из программы (можно написать выход в свободной форме, рекомендую использовать цикл `while`). Если пользователь решил продолжить, то необходимо считать пример функцией `get_input` и посчитать значение функцией `arithmetic`, вывести полученный результат обратно в консоль.

# %%
from typing import Tuple, Union


def arithmetic(first: int, second: int, operator: str) -> Union[int, str]:
    # your code here
    pass


def get_input() -> Tuple[int, int, str]:
    # your code here
    pass


def main() -> None:
    # your code here
    pass
